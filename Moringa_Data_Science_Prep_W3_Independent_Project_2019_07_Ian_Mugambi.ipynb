# %%
# we import the Python libraries we will need for data analysis
import numpy as np
import pandas as pd

# we load the CSV files that we will be analysing
cells_geo_df = pd.read_csv('cells_geo.csv', delimiter = ';', index_col=0)
cells_geo_df.head()

#we load the cells geo descirption file to understand the columns on the celles geo file better
#df = pd.read_csv('cells_geo_description.xlsx')
#df.head()
# Out:
#     VILLES      STATUS LOCALISATION  ... AREA     CELL_ID   SITE_CODE
# 0   ADJAME  In Service      ABIDJAN  ...  NaN  fbb2e75af3  0bb492ef17
# 1   ADJAME  In Service      ABIDJAN  ...  NaN  1502501d78  0bb492ef17
# 2   ADJAME  In Service      ABIDJAN  ...  NaN  0c2e182a0c  0bb492ef17
# 3  ASSINIE  In Service    INTERIEUR  ...  NaN  69bdfc69fd  8a1e6ce31f
# 4  ASSINIE  In Service    INTERIEUR  ...  NaN  7a1029d2ab  8a1e6ce31f
#
# [5 rows x 11 columns]

# %%
#we run the shape command to get a view of volume of data that we are dealing with i.e. #the columns and rows we are dealing with
print(cells_geo_df.shape)
# Out:
# (3974, 11)

# %%
#we want to check how many cities we have where MTN Ivory coast operates using the unique method
pd.unique(cells_geo_df['VILLES'])
# Out:
# array(['ADJAME', 'ASSINIE', 'KRIKOREA', 'ABOBO', 'BINGERVILLE', 'PLATEAU',
#        'DALOA', 'ABENGOUROU', 'ATTECOUBE', 'ABOISSO COMOE', 'ABOISSO',
#        'BONGOUANOU', 'ABONGOUA', 'ABOUDEKOUASSIKRO', 'ABRONAMOUE',
#        'YOPOUGON', 'ADAOU', 'ADDAH', 'ADEBEM', 'ADIAKE', 'ADJAMENE',
#        'PORT-BOUET', 'ADZOPE', 'AFFERY', 'COCODY', 'AGBOVILLE',
#        'AGNIBILEKRO', 'AGONDA', 'AGOU', 'MARCORY', 'AHIZABRO', 'AHOUANOU',
#        'BOUAKE', 'AKOBOISSUE', 'AKOUPE', 'AKOUYAKRO', 'AKRADJO',
#        'KOUMASSI', 'ALEPE', 'ALERIA', 'BAMORO', 'ALLOKOI', 'ANANDA',
#        'ANDO', 'ANDOKOKRENOU', 'ANIANSUE', 'ANOUMABA', 'ANYAMA',
#        'AOUNIANFOUTOU', 'APPOISSO', 'ARRAH', 'ASSIKOI', 'ASSUEFRY',
#        'ATTIGUEHI', 'ATTINGUIE', 'ATTROBROU', 'AYAME', 'AYAPRIKRO',
#        'AZAGUIE', 'BACANDA', 'BADIKAHA', 'BAGOHOUO', 'BAHOMPA',
#        'BACOUBLY', 'BALEKO', 'SAN-PEDRO', 'BANADJE', 'BANANKORO',
#        'BANDAKANY', 'BANDIAHI', 'BANGOLO', 'BANIA', 'BANTEAPLEU',
# ...

# %%
#We see how any cells we have per city uusing the group by function on VILLES and count the SITE_CODE
Cells_geo_grouped_bycity = cells_geo_df.groupby('VILLES')["SITE_CODE"].count()
print(Cells_geo_grouped_bycity)
# Out:
# VILLES
# ABENGOUROU        21
# ABOBO            255
# ABOISSO           18
# ABOISSO COMOE      3
# ABONGOUA           3
#                 ...
# ZATTA              3
# ZIKISSO            4
# ZON-HOUNIEN        3
# ZOUKOUGBEU         3
# ZUENOULA           9
# Name: SITE_CODE, Length: 504, dtype: int64

# %%
#we load the Telcom dataset and load the first 5 commands to give us an uderstanding of the data
Telcom_dataset_df = pd.read_csv('Telcom_dataset.csv', delimiter = ',', index_col=0)
Telcom_dataset_df.head()
# Out:
#          VALUE               DATETIME  ...     CELL_ID     SITE_ID
# PRODUTC                                ...
# Voice        0  2012-05-06 23:04:37.0  ...  /TJNe+Mmtu  /TJNe+Mmtu
# sms          0  2012-05-06 23:05:25.0  ...  /+cKZKIp41  /+cKZKIp41
# sms         25  2012-05-06 23:05:41.0  ...  /u0FSD+ahi  /u0FSD+ahi
# Voice       56  2012-05-06 23:05:42.0  ...  +cNeJzsTp3  +cNeJzsTp3
# Voice       14  2012-05-06 23:06:29.0  ...  051KhYDCpv  051KhYDCpv
#
# [5 rows x 9 columns]

# %%
#we run the shape command to get a view of volume of data that we are dealing with i.e. #the columns and rows we are dealing with
print(Telcom_dataset_df.shape)
# Out:
# (5001, 9)

# %%
#we drop the cells on site and sender and reciever numbers which are not needed
Telcom_dataset_cleanup = Telcom_dataset_df.drop(['DW_A_NUMBER_INT','DW_B_NUMBER_INT'], axis = 1)

# %%
#we check on the characterstics of the data i.e. tota number of values and unique times using the describe method
Telcom_dataset_df['DATETIME'].describe()
# Out:
# count                      5001
# unique                      708
# top       2012-05-07 00:00:10.0
# freq                         71
# Name: DATETIME, dtype: object

# %%
Telcom_dataset_Groupedbytime = Telcom_dataset_df.groupby('SITE_ID')["DATETIME"].count()
print(Telcom_dataset_Groupedbytime)
# Out:
# SITE_ID
# ++ctND+jGD    4
# +38u2u/rfx    4
# +854AcBQT2    4
# +Fs4mTvdKx    2
# +QZ9qRtNxA    2
#              ..
# feb5ccbbd7    3
# feffc8c92b    1
# ff1b78ec81    2
# ffa6bdc032    5
# fff5ac6e3f    3
# Name: DATETIME, Length: 1076, dtype: int64

# %%
#we sort the data to find the sites that had the most traffic
Telcom_dataset_Sortedbysite = Telcom_dataset_df.sort_values(['SITE_ID','DATETIME'],ascending=[True,False])
#pandas.set_option('display.max_rows',None)
print(Telcom_dataset_Sortedbysite.head)
# Out:
# <bound method NDFrame.head of          VALUE               DATETIME  ...     CELL_ID     SITE_ID
# PRODUTC                                ...
# Voice       64  2012-05-06 23:35:25.0  ...  ++ctND+jGD  ++ctND+jGD
# sms          0  2012-05-06 23:28:11.0  ...  ++ctND+jGD  ++ctND+jGD
# sms          0  2012-05-06 23:22:06.0  ...  ++ctND+jGD  ++ctND+jGD
# Voice       44  2012-05-06 23:09:54.0  ...  ++ctND+jGD  ++ctND+jGD
# Voice        2  2012-05-06 23:47:28.0  ...  +38u2u/rfx  +38u2u/rfx
# ...        ...                    ...  ...         ...         ...
# data         0  2012-05-07 00:00:01.0  ...  ffa6759bb2         NaN
# data         0  2012-05-07 00:00:01.0  ...  ffa6759bb2         NaN
# data         0  2012-05-07 00:00:00.0  ...  ffa6759bb2         NaN
# data         0  2012-05-07 00:00:00.0  ...  ffa6759bb2         NaN
# data         0  2012-05-07 00:00:00.0  ...  ffa6759bb2         NaN
#
# [5001 rows x 9 columns]>
